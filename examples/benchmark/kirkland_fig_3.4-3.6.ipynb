# %% [markdown]
# # Kirkland Fig. 3.4 & 3.6

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
from tensorwaves.transfer import PhaseAberration, CTF, TemporalEnvelope
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
aberrations = PhaseAberration(energy=200e3)
aberrations.parametrization.defocus = -600
aberrations.parametrization.Cs = 1e7

k, phi = aberrations.line_data(0, k_max=.8, n=256)

plt.plot(k, phi.numpy().imag)

aberrations.parametrization.defocus = -660
k, phi = aberrations.line_data(0, k_max=.8, n=256)

plt.plot(k, phi.numpy().imag)
plt.ylabel('MTF')
plt.xlabel('Spatial Frequency (in 1/Å)')
# Out:
# Text(0.5, 0, 'Spatial Frequency (in 1/Å)')

# %%
# TODO : include partial spatial coherence to match Kirkland figure

ctf = CTF(energy=200e3)
ctf.aberrations.parametrization.defocus = -600
ctf.aberrations.parametrization.Cs = 1e7

k, phi = ctf.line_data(0, k_max=.8, n=256)
plt.plot(k, phi.numpy().imag)

ctf.temporal_envelope.focal_spread = 100
k, phi = ctf.line_data(0, k_max=.8, n=256)

plt.plot(k, phi.numpy().imag)
plt.ylabel('MTF')
plt.xlabel('Spatial Frequency (in 1/Å)')
# Out:
# Text(0.5, 0, 'Spatial Frequency (in 1/Å)')
