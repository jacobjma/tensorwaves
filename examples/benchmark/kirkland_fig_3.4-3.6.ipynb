# %% [markdown]
# # Kirkland Fig. 3.4 & 3.6

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
from tensorwaves.transfer import PolarAberrations, CTF
import tensorflow as tf
import numpy as np

# %%
aberrations = PolarAberrations(energy=200e3)
aberrations.defocus = -600
aberrations.Cs = 1e7

alpha, phi = aberrations.line_profile()

plt.plot(alpha, phi.numpy().imag)

aberrations.defocus = -660
alpha, phi = aberrations.line_profile()

plt.plot(alpha, phi.numpy().imag)
plt.ylabel('MTF')
plt.xlabel('Spatial Frequency (in 1/Å)')
# Out:
# Text(0.5, 0, 'Spatial Frequency (in 1/Å)')

# %%
# TODO : include partial spatial coherence to match Kirkland figure

ctf = CTF(energy=200e3)
ctf.aberrations.defocus = -600
ctf.aberrations.Cs = 1e7

k, phi = ctf.line_profile()
plt.plot(k, phi.numpy().imag)

ctf.temporal_envelope.focal_spread = 100

k, phi = ctf.line_profile()

plt.plot(k, phi.numpy().imag)
plt.ylabel('MTF')
plt.xlabel('Spatial Frequency (in 1/Å)')
# Out:
# Text(0.5, 0, 'Spatial Frequency (in 1/Å)')
